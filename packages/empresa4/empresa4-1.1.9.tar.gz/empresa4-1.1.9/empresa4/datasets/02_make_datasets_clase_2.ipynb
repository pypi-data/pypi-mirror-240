# %%
import pandas as pd
import numpy as np

# %%
# Reading the CSV file
original_data = pd.read_csv("./originales_clase_3/tb_sellout_02.txt.gz", sep="\t")
original_categories = pd.read_csv("./maestro_productos.csv")

# %%
original_data["periodo"].value_counts().sort_index()
# Out:
# periodo
# 201701     78830
# 201702     82270
# 201703     90603
# 201704     82837
# 201705     96042
# 201706     96169
# 201707     74514
# 201708     92535
# 201709     91287
# 201710     92731
# 201711     92348
# 201712     79841
# 201801     81199
# 201802     84022
# 201803    101066
# 201804     81959
# 201805     85520
# 201806     89551
# 201807     76695
# 201808     88104
# 201809     74621
# 201810     80148
# 201811     72280
# 201812     70166
# 201901     67628
# 201902     82519
# 201903     89520
# 201904     77818
# 201905     73404
# 201906     81994
# 201907     81676
# 201908     66735
# 201909     81197
# 201910     76624
# 201911     73443
# 201912     57922
# Name: count, dtype: int64

# %%
original_data["product_id"].nunique(), original_data["customer_id"].nunique(), original_data["periodo"].nunique()
# Out:
# (1233, 597, 36)

# %%
df = original_data

# %%
df[df["plan_precios_cuidados"] == 1]
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados  \
# 15380     201701        10347       20405                      1
# 15381     201701        10174       20405                      1
# 15382     201701        10413       20405                      1
# 15383     201701        10042       20405                      1
# 15384     201701        10050       20405                      1
# ...          ...          ...         ...                    ...
# 2944586   201912        10173       20323                      1
# 2944587   201912        10313       20323                      1
# 2944588   201912        10064       20323                      1
# 2944589   201912        10015       20323                      1
# 2944590   201912        10017       20323                      1
#
#          cust_request_qty  cust_request_tn       tn
# 15380                 1.0          0.03276  0.03276
# 15381                 5.0          0.13104  0.13104
# 15382                 1.0          0.02457  0.02457
# 15383                 1.0          0.04914  0.04914
# 15384                 1.0          0.08190  0.08190
# ...                   ...              ...      ...
# 2944586               1.0          0.03320  0.03320
# 2944587               1.0          0.01660  0.01660
# 2944588               2.0          0.07469  0.07469
# 2944589               4.0          2.32378  2.32378
# 2944590               2.0          3.78444  3.08730
#
# [34029 rows x 7 columns]

# %%
df[df["product_id"] == 20405]["plan_precios_cuidados"].value_counts()
# Out:
# plan_precios_cuidados
# 0    2299
# 1     368
# Name: count, dtype: int64

# %%
df['periodo'] = df['periodo'].astype(int)
df['product_id'] = df['product_id'].astype(int)
df['customer_id'] = df['customer_id'].astype(int)
df['cust_request_qty'] = df['cust_request_qty'].astype(float)
df['cust_request_tn'] = df['cust_request_tn'].astype(float)
df['tn'] = df['tn'].astype(float)

# %%
print(df["cust_request_qty"].sum(), df["cust_request_tn"].sum(), df["tn"].sum())
# Out:
# 6329834.0 1353074.0208099994 1324988.5884099994

# %%
# print unique number of customer_id, product_id, and period
print(df["customer_id"].nunique(), df["product_id"].nunique(), df["periodo"].nunique())
# Out:
# 597 1233 36

# %%
df_clientes = df.groupby(['customer_id', 'periodo'])[['cust_request_qty', 'cust_request_tn', 'tn']].sum()
df_productos = df.groupby(['product_id', 'periodo'])[['cust_request_qty', 'cust_request_tn', 'tn']].sum()

# %%
print("ORIGINAL", df["cust_request_qty"].sum(), df["cust_request_tn"].sum(), df["tn"].sum())
print("CLIENTES", df_clientes["cust_request_qty"].sum(), df_clientes["cust_request_tn"].sum(), df_clientes["tn"].sum())
print("PRODUCTOS", df_productos["cust_request_qty"].sum(), df_productos["cust_request_tn"].sum(), df_productos["tn"].sum())
# Out:
# ORIGINAL 6329834.0 1353074.0208099994 1324988.5884099994
# CLIENTES 6329834.0 1353074.02081 1324988.58841
# PRODUCTOS 6329834.0 1353074.02081 1324988.5884099999

# %%
df_productos.reset_index(inplace=True)

# %%
df_productos = pd.merge(df_productos, original_categories[['product_id', 'cat1']], on='product_id', how='left')
df_productos.rename(columns={'cat1': 'product_category'}, inplace=True)
df_productos
# Out:
#        product_id  periodo  cust_request_qty  cust_request_tn          tn  \
# 0           20001   201701             479.0        937.72717   934.77222
# 1           20001   201702             432.0        833.72187   798.01620
# 2           20001   201703             509.0       1330.74697  1303.35771
# 3           20001   201704             279.0       1132.94430  1069.96130
# 4           20001   201705             701.0       1550.68936  1502.20132
# ...           ...      ...               ...              ...         ...
# 31238       21295   201701               1.0          0.00699     0.00699
# 31239       21296   201708               1.0          0.00651     0.00651
# 31240       21297   201701               1.0          0.00579     0.00579
# 31241       21298   201708               1.0          0.00573     0.00573
# 31242       21299   201708               1.0          0.00546     0.00546
#
#       product_category
# 0                   HC
# 1                   HC
# 2                   HC
# 3                   HC
# 4                   HC
# ...                ...
# 31238              NaN
# 31239              NaN
# 31240              NaN
# 31241              NaN
# 31242              NaN
#
# [31243 rows x 6 columns]

# %%
df_producto_estrella = df_productos[df_productos['product_id'] == 20001]

# %%
df_producto_estrella
# Out:
#     product_id  periodo  cust_request_qty  cust_request_tn          tn  \
# 0        20001   201701             479.0        937.72717   934.77222
# 1        20001   201702             432.0        833.72187   798.01620
# 2        20001   201703             509.0       1330.74697  1303.35771
# 3        20001   201704             279.0       1132.94430  1069.96130
# 4        20001   201705             701.0       1550.68936  1502.20132
# 5        20001   201706             570.0       1575.82891  1520.06539
# 6        20001   201707             381.0       1086.47101  1030.67391
# 7        20001   201708             643.0       1289.66869  1267.39462
# 8        20001   201709             381.0       1356.96103  1316.94604
# 9        20001   201710             273.0       1441.60247  1439.75563
# 10       20001   201711             519.0       1586.94356  1580.47401
# 11       20001   201712             435.0       1098.83929  1049.38860
# 12       20001   201801             437.0       1256.01136  1169.07532
# 13       20001   201802             302.0       1150.37849  1043.76470
# 14       20001   201803             591.0       1902.79056  1856.83534
# 15       20001   201804             384.0       1286.12277  1251.28462
# 16       20001   201805             456.0       1303.62129  1293.89788
# 17       20001   201806             497.0       1198.50145  1150.79169
# 18       20001   201807             458.0       1528.59380  1470.41009
# 19       20001   201808             535.0       1859.88471  1800.96168
# 20       20001   201809             401.0       1629.37910  1438.67455
# 21       20001   201810             417.0       2423.70881  2295.19832
# 22       20001   201811             447.0       1945.84961  1813.01511
# 23       20001   201812             453.0       1562.28968  1486.68669
# 24       20001   201901             370.0       1371.76430  1275.77351
# 25       20001   201902             367.0       1343.99435  1259.09363
# 26       20001   201903             454.0       1607.18772  1470.65653
# 27       20001   201904             478.0       1757.73271  1647.63848
# 28       20001   201905             308.0       1694.39604  1629.78233
# 29       20001   201906             396.0       1261.53572  1109.93769
# 30       20001   201907             432.0       1782.81423  1678.99318
# 31       20001   201908             365.0       1263.13762  1261.34529
# 32       20001   201909             392.0       1734.24194  1660.00561
# 33       20001   201910             367.0       1587.87525  1561.50552
# 34       20001   201911             392.0       1446.07905  1397.37231
# 35       20001   201912             407.0       1650.46149  1504.68856
#
#    product_category
# 0                HC
# 1                HC
# 2                HC
# 3                HC
# 4                HC
# 5                HC
# 6                HC
# 7                HC
# 8                HC
# 9                HC
# 10               HC
# 11               HC
# 12               HC
# 13               HC
# 14               HC
# 15               HC
# 16               HC
# 17               HC
# 18               HC
# 19               HC
# 20               HC
# 21               HC
# 22               HC
# 23               HC
# 24               HC
# 25               HC
# 26               HC
# 27               HC
# 28               HC
# 29               HC
# 30               HC
# 31               HC
# 32               HC
# 33               HC
# 34               HC
# 35               HC

# %%
df_clientes
# Out:
#                      cust_request_qty  cust_request_tn          tn
# customer_id periodo
# 10001       201701             4013.0       2567.40529  2543.89944
#             201702             2923.0       3010.01367  3007.08273
#             201703             5848.0       3820.64849  3772.79718
#             201704             4474.0       3333.73931  3283.44204
#             201705             5328.0       3761.19311  3753.20470
# ...                               ...              ...         ...
# 10634       201702               17.0          0.10288     0.10288
# 10635       201701               22.0          0.06083     0.06083
#             201703               29.0          0.03446     0.03446
# 10636       201702                5.0          0.03605     0.03605
# 10637       201709                2.0          0.00288     0.00288
#
# [16492 rows x 3 columns]

# %%
# Find all unique values for 'periodo' and 'product_id'
unique_periodos = df['periodo'].unique()
unique_product_ids = df['product_id'].unique()
unique_customer_ids = df['customer_id'].unique()
len(unique_periodos), len(unique_product_ids), len(unique_customer_ids)
# Out:
# (36, 1233, 597)

# %%
print("Shape antes: ", df_productos.shape)

from itertools import product

# Create all possible combinations of 'periodo' and 'product_id'
all_combinations = list(product(unique_periodos, unique_product_ids))

# Convert the combinations into a DataFrame
all_combinations_df = pd.DataFrame(all_combinations, columns=['periodo', 'product_id'])

# Merge with the existing DataFrame to find missing rows
combined_df = all_combinations_df.merge(df_productos, on=['periodo', 'product_id'], how='left')

# Identify the missing rows by looking for NaNs
missing_rows = combined_df[combined_df['cust_request_qty'].isna()]

# For the missing rows, set 'cust_request_qty', 'cust_request_tn', and 'tn' to 0
# We also need to decide how to handle 'product_category'. For now, we'll set it as 'Unknown'
missing_rows.loc[:, 'cust_request_qty'] = 0
missing_rows.loc[:, 'cust_request_tn'] = 0
missing_rows.loc[:, 'tn'] = 0

# Look for other row with this product_id and asign the category
for index, row in missing_rows.iterrows():
    product_id = row['product_id']
    product_category = df_productos[df_productos['product_id'] == product_id]['product_category'].values[0]
    missing_rows.loc[index, 'product_category'] = product_category

# Now we append the missing rows to the original DataFrame
# convert to pd.concat: complete_df = df_productos.append(missing_rows[df_productos.columns], ignore_index=True)
df_productos = pd.concat([df_productos, missing_rows[df_productos.columns]], ignore_index=True)

# Return the number of new rows added and the path to the new file
num_new_rows = len(missing_rows)
print(num_new_rows)

print("Shape Después: ", df_productos.shape)
# Out:
# Shape antes:  (31243, 6)
# 13145
# Shape Después:  (44388, 6)

# %%
# Debería tener resto 0
print(df_productos.shape[0] / 36)
# Out:
# 1233.0

# %%
print("Shape antes: ", df_clientes.shape)
print(df_clientes.shape[0] / 36)

from itertools import product

# Create all possible combinations of 'periodo' and 'product_id'
all_combinations = list(product(unique_periodos, unique_customer_ids))

# Convert the combinations into a DataFrame
all_combinations_df = pd.DataFrame(all_combinations, columns=['periodo', 'customer_id'])

# Merge with the existing DataFrame to find missing rows
combined_df = all_combinations_df.merge(df_clientes, on=['periodo', 'customer_id'], how='left')

# Identify the missing rows by looking for NaNs
missing_rows = combined_df[combined_df['cust_request_qty'].isna()]

# For the missing rows, set 'cust_request_qty', 'cust_request_tn', and 'tn' to 0
# We also need to decide how to handle 'product_category'. For now, we'll set it as 'Unknown'
missing_rows.loc[:, 'cust_request_qty'] = 0
missing_rows.loc[:, 'cust_request_tn'] = 0
missing_rows.loc[:, 'tn'] = 0

# Now we append the missing rows to the original DataFrame
# convert to pd.concat: complete_df = df_productos.append(missing_rows[df_productos.columns], ignore_index=True)
df_clientes = pd.concat([df_clientes, missing_rows[df_clientes.columns]], ignore_index=True)

# Return the number of new rows added and the path to the new file
num_new_rows = len(missing_rows)
print(num_new_rows)

print("Shape Después: ", df_clientes.shape)

# Debería tener resto 0
print(df_clientes.shape[0] / 36)
# Out:
# Shape antes:  (16492, 3)
# 458.1111111111111
# 5000
# Shape Después:  (21492, 3)
# 597.0

# %%
print("ORIGINAL", df["cust_request_qty"].sum(), df["cust_request_tn"].sum(), df["tn"].sum())
print("CLIENTES", df_clientes["cust_request_qty"].sum(), df_clientes["cust_request_tn"].sum(), df_clientes["tn"].sum())
print("PRODUCTOS", df_productos["cust_request_qty"].sum(), df_productos["cust_request_tn"].sum(), df_productos["tn"].sum())
# Out:
# ORIGINAL 6329834.0 1353074.0208099994 1324988.5884099994
# CLIENTES 6329834.0 1353074.02081 1324988.58841
# PRODUCTOS 6329834.0 1353074.02081 1324988.5884099999

# %%
df.to_csv('tb_sellout_02_original.csv', index=False)
df_producto_estrella.to_csv('tb_sellout_02_producto_estrella.csv', index=False)
df_productos.to_csv('tb_sellout_02_productos_todos.csv', index=False)
df_clientes.to_csv('tb_sellout_02_por_cliente.csv', index=True)
