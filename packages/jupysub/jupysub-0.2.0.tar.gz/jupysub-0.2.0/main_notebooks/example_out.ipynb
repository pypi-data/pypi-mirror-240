# %% [markdown]
# ## Test file for most actions performed by the python parser
#
# <div class="alert alert-block alert-success">
# <b>Green one</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Just useful snake comments </b>  Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>
#
# <blockquote class="panel-default">
#      “Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum nec placerat nibh, quis finibus turpis. Mauris auctor leo ut augue commodo ultrices. Integer egestas sed dolor vel cursus. Nam dignissim interdum massa.”
# <small>Lorem Ipsum | Class of 2019</small>
#     </blockquote>
#
# <blockquote class="alert-info">
#      “Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum nec placerat nibh, quis finibus turpis. Mauris auctor leo ut augue commodo ultrices. Integer egestas sed dolor vel cursus. Nam dignissim interdum massa.”
# <small>Lorem Ipsum | Class of 2019</small>
# </blockquote>
#
# <blockquote class="alert-success">
#      “Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum nec placerat nibh, quis finibus turpis. Mauris auctor leo ut augue commodo ultrices. Integer egestas sed dolor vel cursus. Nam dignissim interdum massa.”
# <small>Lorem Ipsum | Class of 2019</small>
#     </blockquote>
#
# <blockquote class="alert-warning">
#      “Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum nec placerat nibh, quis finibus turpis. Mauris auctor leo ut augue commodo ultrices. Integer egestas sed dolor vel cursus. Nam dignissim interdum massa.”
# <small>Lorem Ipsum | Class of 2019</small>
#     </blockquote>
#
# <blockquote class="alert-danger">
#      “Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum nec placerat nibh, quis finibus turpis. Mauris auctor leo ut augue commodo ultrices. Integer egestas sed dolor vel cursus. Nam dignissim interdum massa.”
# <small>Lorem Ipsum | Class of 2019</small>
#     </blockquote>
#
# ## Table:
# <table class="table table-striped table-responsive">
#   <thead>
#     <tr>
#       <th>Firstname</th>
#       <th>Lastname</th>
#       <th>Email</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>John</td>
#       <td>Doe</td>
#       <td>john@example.com</td>
#     </tr>
#     <tr>
#       <td>Mary</td>
#       <td>Moe</td>
#       <td>mary@example.com</td>
#     </tr>
#     <tr>
#       <td>July</td>
#       <td>Dooley</td>
#       <td>july@example.com</td>
#     </tr>
#   </tbody>
# </table>
#
# ## Progress bars
# Full documentation on https://getbootstrap.com/docs/3.4/components/#progress
# <div class="progress">
#   <div class="progress-bar progress-bar-success progress-bar-striped active" role="progressbar" aria-valuenow="40" aria-valuemin="0" aria-valuemax="100" style="width: 40%">
#     <span class="sr-only">40% Complete (success)</span>
#   </div>
# </div>
# <div class="progress">
#   <div class="progress-bar progress-bar-info progress-bar-striped" role="progressbar" aria-valuenow="20" aria-valuemin="0" aria-valuemax="100" style="width: 20%">
#     <span class="sr-only">20% Complete</span>
#   </div>
# </div>
# <div class="progress">
#   <div class="progress-bar progress-bar-warning progress-bar-striped active" role="progressbar" aria-valuenow="60" aria-valuemin="0" aria-valuemax="100" style="width: 60%">
#     <span class="sr-only">60% Complete (warning)</span>
#   </div>
# </div>
# <div class="progress">
#   <div class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" aria-valuenow="80" aria-valuemin="0" aria-valuemax="100" style="width: 80%">
#     <span class="sr-only">80% Complete (danger)</span>
#   </div>
# </div>

# %% [markdown]
# ## Question 1: Heat transfer <span style="font-size: 10pt;"><span style="opacity: 1;">🧠🧠🧠</span><span style="opacity: 0.1;">🧠🧠</span></span>
#
# Loren ipsum

# %% [markdown]
# ## Question 2: Another Heat transfer <span style="font-size: 10pt;"><span style="opacity: 1;">🧠🧠</span><span style="opacity: 0.1;">🧠🧠🧠</span></span>
#
# Loren ipsum another

# %% [markdown]
# ## Introduction to This Template Notebook
#
# **How to use?**:
# * Run the code cell by putting the cursor there and pressing **Control-Enter**.
#
# * The locations where you should write your solutions can be recognized by the following comment.
#
# * Double-clicking markdown cells will reveal their content. Press **Control-Enter** to make the cells user-friendly again.
#
# ><code># WRITE YOUR CODE HERE</code>
#
# **Make sure to clear your variables using <code>%reset -f</code> when you are done with an exercise and run it from top to bottom**
#
# <hr style="border:2px solid #eee">

# %%
# from IPython.core.display import display, HTML, Javascript
# display(HTML("""<div class="progress">
#   <div id="dynamic" class="progress-bar progress-ba
# r-success progress-bar-striped active" role="progressbar" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100" style="width: 0%">
#     <span id="current-progress"></span>

#   </div>
# </div>"""))

# %% [markdown]
# **Functions for documentation testing**
#
# Some multiline code:
# ```python
# import numpy as plt
# import importlib as np
# import matplotlib as tk
# ```
#
# Plots:
#
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html">plt.plot</a>(x, y, fmt)</code>: Plots a line or marker-based plot of <code>y</code> versus <code>x</code> using the specified format string <code>fmt</code> ("o" for only dots, "-o" for line and dots and "-" for only line).
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html">plt.scatter</a>(x, y, s, c)</code>: Creates a scatter plot of <code>x</code> versus <code>y</code> with marker size <code>s</code> and color <code>c</code>.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html">plt.bar</a>(x, height)</code>: Creates a bar chart with bars at positions <code>x</code> and given <code>height</code>.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html">plt.hist</a>(data, bins, color, alpha)</code>: Plots a histogram of the <code>data</code> with specified <code>bins</code>, <code>color</code>, and <code>alpha</code> (transparency).
#
# <br>
#
# Labels:
#
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html">plt.xlabel</a>(label)</code>: Sets the label for the x-axis.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html">plt.ylabel</a>(label)</code>: Sets the label for the y-axis.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html">plt.title</a>(title)</code>: Sets the title of the plot.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.legend(*args, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html">plt.legend</a>()</code>: Adds a legend to the plot.
#
# <br>
#
# Grid:
#
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.xlim(*args, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html">plt.xlim</a>(left, right)</code>: Sets the limits of the x-axis to the values left and right.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.ylim(*args, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html">plt.ylim</a>(bottom, top)</code>: Sets the limits of the y-axis to the values bottom and top.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.xticks(ticks=None, labels=None, *, minor=False, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html">plt.xticks</a>(ticks, labels)</code>: Sets the x-axis tick locations and labels.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.yticks(ticks=None, labels=None, *, minor=False, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.yticks.html">plt.yticks</a>(ticks, labels)</code>: Sets the y-axis tick locations and labels.
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html">plt.grid</a>(b)</code>: Adds a grid to the plot (True or False).
#
# <br>
#
# Show, save plot:
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.savefig(*args, **kwargs)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html">plt.savefig</a>(filename)</code>: Saves the current figure to a file with the specified filename and file format (e.g., .png, .pdf).
# - <code><a style="text-decoration: none;" title="matplotlib.pyplot.show(*, block=None)" href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html">plt.show</a>()</code>: Displays the current figure.
#
# Fancy example:
# - <code><a style="text-decoration: none;" title="numpy.array(object, dtype=None, *, copy=True, order='K', subok=False, ndmin=0, like=None)" href="https://numpy.org/doc/stable/reference/generated/numpy.array.html">np.array</a>([<a style="text-decoration: none;" title="numpy.max(a, axis=None, out=None, keepdims=<no value>, initial=<no value>, where=<no value>)" href="https://numpy.org/doc/stable/reference/generated/numpy.max.html">np.max</a>([1,2]), <a style="text-decoration: none;" title="linalg.norm(x, ord=None, axis=None, keepdims=False)" href="https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html">np.linalg.norm</a>(<a style="text-decoration: none;" title="random.rand(d0, d1, ..., dn)" href="https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html">np.random.rand</a>(3))])</code>
#
#
# Look ma, some standard library functions:
#
# - <code><a style="text-decoration: none;" title="print(*objects, sep=' ', end='\n', file=None, flush=False)" href="https://docs.python.org/3/library/functions.html#print">print</a>("hello world")</code>
# - <code><a style="text-decoration: none;" title="itertools.product(*iterables, repeat=1)" href="https://docs.python.org/3/library/itertools.html#itertools.product">itertools.product</a>(stuff)</code>
# - <code><a style="text-decoration: none;" title="class pathlib.Path(*pathsegments)" href="https://docs.python.org/3/library/pathlib.html#pathlib.Path">pathlib.Path</a>("./here")</code>
# - <code><a style="text-decoration: none;" title="max(iterable, *, key=None)" href="https://docs.python.org/3/library/functions.html#max">max</a>([n for n in bunch_of_numbers])</code>
# - <code><a style="text-decoration: none;" title="min(iterable, *, key=None)" href="https://docs.python.org/3/library/functions.html#min">min</a>([m for m in [<a style="text-decoration: none;" title="max(iterable, *, key=None)" href="https://docs.python.org/3/library/functions.html#max">max</a>(<a style="text-decoration: none;" title="print(*objects, sep=' ', end='\n', file=None, flush=False)" href="https://docs.python.org/3/library/functions.html#print">print</a>(b),1) for b in <a style="text-decoration: none;" title="range(stop)
# range(start, stop, step=1)" href="https://docs.python.org/3/library/functions.html#range">range</a>(20)]])</code>
#
# Look ma, some data types:
#
# - <code><a style="text-decoration: none;" title="int(x=0)" href="https://docs.python.org/3/library/functions.html#int">int</a>(25)</code>
# - <code>[<a style="text-decoration: none;" title="float(x=0.0)" href="https://docs.python.org/3/library/functions.html#float">float</a>(j) for i in <a style="text-decoration: none;" title="range(stop)
# range(start, stop, step=1)" href="https://docs.python.org/3/library/functions.html#range">range</a>(25) for j in <a style="text-decoration: none;" title="itertools.product(*iterables, repeat=1)" href="https://docs.python.org/3/library/itertools.html#itertools.product">itertools.product</a>(<a style="text-decoration: none;" title="range(stop)
# range(start, stop, step=1)" href="https://docs.python.org/3/library/functions.html#range">range</a>(25),repeat=1)]</code>

# %% [markdown]
# ### ANSWER, EXCLUDE AND EXPECTED OUTPUT
#
# <div class="alert alert-block alert-info"  style="border-radius: 6px;" ><b>Hint:</b>  You can use the <code>numpy</code> library for arrays.</div>
#
# <div class="alert alert-block alert-danger"  style="border-radius: 6px;" ><b>Caution:</b>  Wrong indexing can lead to memory leaks (in C)</div>
#
# <div class="alert alert-block alert-info"  style="border-radius: 6px;" ><b>Tip:</b>  Store your variables in a dictionary. </div>

# %%
# importing libraries 
# ADD YOUR CODE HERE

# Defining the rate function
# ADD YOUR CODE HERE

# Defining parameters
# ADD YOUR CODE HERE

# Integrating 
# ADD YOUR CODE HERE

# Getting analytical solution
# ADD YOUR CODE HERE

# Plotting (optional) uncomment to see result
#plt.plot(t, c, "o", mfc='none', label="Numeric integral")
#plt.plot(t, c_ana, "-", label = "Analytical solution")
#plt.xlabel("t [s]")
#plt.ylabel("c [mol/dm3]")
#plt.legend()
#plt.grid()
#plt.show()

# %% [markdown]
# <details ><summary  style="margin: 0px 0px; color: #3498db; font-size: 13pt;" >Expected solution</summary><div  style="padding: 5px; font-family: monospace; font-size: 10pt; overflow: auto; border: 1px solid gray; border-radius: 5px; margin: 5px 0px 5px 0px; white-space: pre-wrap;" class="" ><code>cstr_params=</code> {'tau': 1, 'cin': 0}
# <code>cstr_params=</code> {'tau': 1, 'cin': 0}
# <code>cstr_params=</code> {'tau': 1, 'cin': 0}
# <code>t.shape</code> = (50,)
# <code>c.shape</code> = (50, 1)
# <code>c_analytical.shape</code>= (50, 1)
#
# <img  style="display: inline-block;" src="data:image/png;base64,..." ><br>
# EXTRA code after figure?
# </div></details>

# %% [markdown]
# ### IGNORE EXPECTED OUTPUT AND EXCLUDE

# %%
#! IGNORE EXPECTED OUTPUT
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Ensuring reproducibility
np.random.seed(0)

# Generating the function to be fitted
def f(x, a, b, c):
  return a/(b + np.exp(-c*x))

# Generating the data
a, b, c = 10, 2, 3 # Coefficients to be fitted
x = np.linspace(-3, 3, 200)
noise = np.random.rand(len(x))-0.5
y = f(x, a, b, c) + noise

# Fitting
initial_guess = [1, 1, 1]
fit_params, _ = curve_fit(f, x, y, p0 = initial_guess)

# Unpacking the fit constants
a_fit, b_fit, c_fit = fit_params

# Print the results with 4 decimal places accuracy
print("Original Coefficients: a={:.4f}, b={:.4f}, c={:.4f}".format(a, b, c))
print("Fitted Coefficients:   a={:.4f}, b={:.4f}, c={:.4f}".format(a_fit, b_fit, c_fit))

# Visualizing the fit
plt.plot(x, y, "o", mfc="none", label="data")
plt.plot(x, f(x, a_fit, b_fit, c_fit), "-", label="fit")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <details ><summary  style="margin: 0px 0px; color: #3498db; font-size: 13pt;" >Expected solution</summary><div  style="padding: 5px; font-family: monospace; font-size: 10pt; overflow: auto; border: 1px solid gray; border-radius: 5px; margin: 5px 0px 5px 0px; white-space: pre-wrap;" class="" >Original Coefficients: a=10.0000, b=2.0000, c=3.0000
# Fitted Coefficients:   a=10.2722, b=2.0550, c=3.2906
#
# <img  style="display: inline-block;" src="data:image/png;base64,..." ><br></div></details>
